# %% [markdown]
# <a href="https://colab.research.google.com/github/YamenObeidat/Machine-Learning-Final-Project-1/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip "*.zip" -d /content/
# Out:
# Archive:  products.csv.zip
#   inflating: /content/products.csv
#
# Archive:  order_products__train.csv.zip
#   inflating: /content/order_products__train.csv
#
# Archive:  order_products__prior.csv.zip
#   inflating: /content/order_products__prior.csv
#
# Archive:  orders.csv.zip
#   inflating: /content/orders.csv
#
# 4 archives were successfully processed.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df1 = pd.read_csv('/content/aisles.csv')
df2 = pd.read_csv('/content/departments.csv')
df3 = pd.read_csv('/content/order_products__prior.csv')
df4 = pd.read_csv('/content/order_products__train.csv')
df5 = pd.read_csv('/content/orders.csv')
df6 = pd.read_csv('/content/products.csv')
columns = list(df1.columns) + list(df2.columns) + list(df3.columns) + list(df4.columns) + list(df5.columns) + list(df6.columns)
print (f"Number of columns: {len(columns)}")
print("DF1 Columns:", df1.columns.tolist())
print("DF2 Columns:", df2.columns.tolist())
print("DF3 Columns:", df3.columns.tolist())
print("DF4 Columns:", df4.columns.tolist())
print("DF5 Columns:", df5.columns.tolist())
print("DF6 Columns:", df6.columns.tolist())
# Out:
# Number of columns: 23
# DF1 Columns: ['aisle_id', 'aisle']
# DF2 Columns: ['department_id', 'department']
# DF3 Columns: ['order_id', 'product_id', 'add_to_cart_order', 'reordered']
# DF4 Columns: ['order_id', 'product_id', 'add_to_cart_order', 'reordered']
# DF5 Columns: ['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']
# DF6 Columns: ['product_id', 'product_name', 'aisle_id', 'department_id']

# %%
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation
# 5         6                       other
# 6         7               packaged meat
# 7         8             bakery desserts
# 8         9                 pasta sauce
# 9        10            kitchen supplies

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
